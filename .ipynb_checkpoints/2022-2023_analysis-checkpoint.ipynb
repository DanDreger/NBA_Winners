# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
season_21_22 = pd.read_csv('./Basketball_Data/2021-2022_season.csv')

# %%
# Drop multiple columns
columns_to_drop = ['Unnamed: 6', 'Unnamed: 7', 'Attend.', 'Arena', 'Notes', 'Start (ET)']
season_21_22.drop(columns=columns_to_drop, axis=1, inplace=True)

season_21_22
# Out:
#                  Date        Visitor/Neutral  PTS            Home/Neutral  \
# 0     Tue Oct 19 2021          Brooklyn Nets  104         Milwaukee Bucks
# 1     Tue Oct 19 2021  Golden State Warriors  121      Los Angeles Lakers
# 2     Wed Oct 20 2021         Indiana Pacers  122       Charlotte Hornets
# 3     Wed Oct 20 2021          Chicago Bulls   94         Detroit Pistons
# 4     Wed Oct 20 2021         Boston Celtics  134         New York Knicks
# ...               ...                    ...  ...                     ...
# 1274  Wed Apr 27 2022         Denver Nuggets   98   Golden State Warriors
# 1275  Thu Apr 28 2022     Philadelphia 76ers  132         Toronto Raptors
# 1276  Thu Apr 28 2022           Phoenix Suns  115    New Orleans Pelicans
# 1277  Thu Apr 28 2022       Dallas Mavericks   98               Utah Jazz
# 1278  Fri Apr 29 2022      Memphis Grizzlies  114  Minnesota Timberwolves
#
#       PTS.1
# 0       127
# 1       114
# 2       123
# 3        88
# 4       138
# ...     ...
# 1274    102
# 1275     97
# 1276    109
# 1277     96
# 1278    106
#
# [1279 rows x 5 columns]

# %%
# Loop through the column names and replace the .1's with Home/Visitor Score
new_column_names = {}
for col in season_21_22.columns:
    if col.endswith('.1'):
        new_column_names[col] = col.replace('PTS.1', 'Home Score')
    elif col.endswith('PTS'):
        new_column_names[col] = col.replace('PTS', 'Visitor Score')

# Rename the columns
season_21_22.rename(columns=new_column_names, inplace=True)

# Rename the Visitor home columns.
season_21_22.rename(columns={
    'Visitor/Neutral': 'Visiting Team',
    'Home/Neutral': 'Home Team'
}, inplace=True)

# Show the DataFrame after renaming columns
season_21_22
# Out:
#                  Date          Visiting Team  Visitor Score  \
# 0     Tue Oct 19 2021          Brooklyn Nets            104
# 1     Tue Oct 19 2021  Golden State Warriors            121
# 2     Wed Oct 20 2021         Indiana Pacers            122
# 3     Wed Oct 20 2021          Chicago Bulls             94
# 4     Wed Oct 20 2021         Boston Celtics            134
# ...               ...                    ...            ...
# 1274  Wed Apr 27 2022         Denver Nuggets             98
# 1275  Thu Apr 28 2022     Philadelphia 76ers            132
# 1276  Thu Apr 28 2022           Phoenix Suns            115
# 1277  Thu Apr 28 2022       Dallas Mavericks             98
# 1278  Fri Apr 29 2022      Memphis Grizzlies            114
#
#                    Home Team  Home Score
# 0            Milwaukee Bucks         127
# 1         Los Angeles Lakers         114
# 2          Charlotte Hornets         123
# 3            Detroit Pistons          88
# 4            New York Knicks         138
# ...                      ...         ...
# 1274   Golden State Warriors         102
# 1275         Toronto Raptors          97
# 1276    New Orleans Pelicans         109
# 1277               Utah Jazz          96
# 1278  Minnesota Timberwolves         106
#
# [1279 rows x 5 columns]

# %%
# Convert to datetime format
season_21_22['Date'] = pd.to_datetime(season_21_22['Date'], format='%a %b %d %Y')

season_21_22
# Out:
#            Date          Visiting Team  Visitor Score               Home Team  \
# 0    2021-10-19          Brooklyn Nets            104         Milwaukee Bucks
# 1    2021-10-19  Golden State Warriors            121      Los Angeles Lakers
# 2    2021-10-20         Indiana Pacers            122       Charlotte Hornets
# 3    2021-10-20          Chicago Bulls             94         Detroit Pistons
# 4    2021-10-20         Boston Celtics            134         New York Knicks
# ...         ...                    ...            ...                     ...
# 1274 2022-04-27         Denver Nuggets             98   Golden State Warriors
# 1275 2022-04-28     Philadelphia 76ers            132         Toronto Raptors
# 1276 2022-04-28           Phoenix Suns            115    New Orleans Pelicans
# 1277 2022-04-28       Dallas Mavericks             98               Utah Jazz
# 1278 2022-04-29      Memphis Grizzlies            114  Minnesota Timberwolves
#
#       Home Score
# 0            127
# 1            114
# 2            123
# 3             88
# 4            138
# ...          ...
# 1274         102
# 1275          97
# 1276         109
# 1277          96
# 1278         106
#
# [1279 rows x 5 columns]

# %%
# Calculate the average of all values in 'Column1'
Visitor_Score_Average = season_21_22['Visitor Score'].mean()
Home_Score_Average = season_21_22['Home Score'].mean()

print(f'Home average is {Home_Score_Average}, Visitor Score Average is {Visitor_Score_Average}. Total Home Court Advantage is {Home_Score_Average-Visitor_Score_Average}')
# Out:
# Home average is 111.3721657544957, Visitor Score Average is 109.64816262705239. Total Home Court Advantage is 1.7240031274433107

# %%
# Create new columns for storing days since last game for Visitor and Home teams
season_21_22['Visitor_Last_Game'] = 0
season_21_22['Home_Last_Game'] = 0

# Dictionary to keep track of the last game date for each team
last_game_date = {}

# Loop through each row of the DataFrame
for index, row in season_21_22.iterrows():
    visitor = row['Visiting Team']
    home = row['Home Team']
    current_date = row['Date']

    # Update Visitor_Last_Game
    if visitor in last_game_date:
        season_21_22.at[index, 'Visitor_Last_Game'] = (current_date - last_game_date[visitor]).days
    last_game_date[visitor] = current_date  # Update the last game date for this visitor team

    # Update Home_Last_Game
    if home in last_game_date:
        season_21_22.at[index, 'Home_Last_Game'] = (current_date - last_game_date[home]).days
    last_game_date[home] = current_date  # Update the last game date for this home team
    
season_21_22.head(60)
# Out:
#          Date           Visiting Team  Visitor Score               Home Team  \
# 0  2021-10-19           Brooklyn Nets            104         Milwaukee Bucks
# 1  2021-10-19   Golden State Warriors            121      Los Angeles Lakers
# 2  2021-10-20          Indiana Pacers            122       Charlotte Hornets
# 3  2021-10-20           Chicago Bulls             94         Detroit Pistons
# 4  2021-10-20          Boston Celtics            134         New York Knicks
# 5  2021-10-20      Washington Wizards             98         Toronto Raptors
# 6  2021-10-20     Cleveland Cavaliers            121       Memphis Grizzlies
# 7  2021-10-20         Houston Rockets            106  Minnesota Timberwolves
# 8  2021-10-20      Philadelphia 76ers            117    New Orleans Pelicans
# 9  2021-10-20           Orlando Magic             97       San Antonio Spurs
# 10 2021-10-20   Oklahoma City Thunder             86               Utah Jazz
# 11 2021-10-20        Sacramento Kings            124  Portland Trail Blazers
# 12 2021-10-20          Denver Nuggets            110            Phoenix Suns
# 13 2021-10-21        Dallas Mavericks             87           Atlanta Hawks
# 14 2021-10-21         Milwaukee Bucks             95              Miami Heat
# 15 2021-10-21    Los Angeles Clippers            113   Golden State Warriors
# 16 2021-10-22         New York Knicks            121           Orlando Magic
# 17 2021-10-22          Indiana Pacers            134      Washington Wizards
# 18 2021-10-22       Charlotte Hornets            123     Cleveland Cavaliers
# 19 2021-10-22         Toronto Raptors            115          Boston Celtics
# 20 2021-10-22           Brooklyn Nets            114      Philadelphia 76ers
# 21 2021-10-22   Oklahoma City Thunder             91         Houston Rockets
# 22 2021-10-22    New Orleans Pelicans            112           Chicago Bulls
# 23 2021-10-22       San Antonio Spurs             96          Denver Nuggets
# 24 2021-10-22            Phoenix Suns            115      Los Angeles Lakers
# 25 2021-10-22               Utah Jazz            110        Sacramento Kings
# 26 2021-10-23           Atlanta Hawks             95     Cleveland Cavaliers
# 27 2021-10-23              Miami Heat             91          Indiana Pacers
# 28 2021-10-23        Dallas Mavericks            103         Toronto Raptors
# 29 2021-10-23         Detroit Pistons             82           Chicago Bulls
# 30 2021-10-23    New Orleans Pelicans             89  Minnesota Timberwolves
# 31 2021-10-23         Milwaukee Bucks            121       San Antonio Spurs
# 32 2021-10-23            Phoenix Suns            105  Portland Trail Blazers
# 33 2021-10-23       Memphis Grizzlies            120    Los Angeles Clippers
# 34 2021-10-24       Charlotte Hornets            111           Brooklyn Nets
# 35 2021-10-24          Boston Celtics            107         Houston Rockets
# 36 2021-10-24           Orlando Magic            110         New York Knicks
# 37 2021-10-24      Philadelphia 76ers            115   Oklahoma City Thunder
# 38 2021-10-24   Golden State Warriors            119        Sacramento Kings
# 39 2021-10-24       Memphis Grizzlies            118      Los Angeles Lakers
# 40 2021-10-25          Boston Celtics            140       Charlotte Hornets
# 41 2021-10-25         Milwaukee Bucks            119          Indiana Pacers
# 42 2021-10-25           Chicago Bulls            111         Toronto Raptors
# 43 2021-10-25           Orlando Magic             90              Miami Heat
# 44 2021-10-25      Washington Wizards             90           Brooklyn Nets
# 45 2021-10-25         Detroit Pistons            104           Atlanta Hawks
# 46 2021-10-25    New Orleans Pelicans            107  Minnesota Timberwolves
# 47 2021-10-25     Cleveland Cavaliers             99          Denver Nuggets
# 48 2021-10-25  Portland Trail Blazers             86    Los Angeles Clippers
# 49 2021-10-26      Philadelphia 76ers             99         New York Knicks
# 50 2021-10-26   Golden State Warriors            106   Oklahoma City Thunder
# 51 2021-10-26      Los Angeles Lakers            125       San Antonio Spurs
# 52 2021-10-26         Houston Rockets            106        Dallas Mavericks
# 53 2021-10-26          Denver Nuggets            110               Utah Jazz
# 54 2021-10-27       Charlotte Hornets            120           Orlando Magic
# 55 2021-10-27      Washington Wizards            116          Boston Celtics
# 56 2021-10-27              Miami Heat            106           Brooklyn Nets
# 57 2021-10-27          Indiana Pacers            100         Toronto Raptors
# 58 2021-10-27           Atlanta Hawks            102    New Orleans Pelicans
# 59 2021-10-27  Minnesota Timberwolves            113         Milwaukee Bucks
#
#     Home Score  Visitor_Last_Game  Home_Last_Game
# 0          127                  0               0
# 1          114                  0               0
# 2          123                  0               0
# 3           88                  0               0
# 4          138                  0               0
# 5           83                  0               0
# 6          132                  0               0
# 7          124                  0               0
# 8           97                  0               0
# 9          123                  0               0
# 10         107                  0               0
# 11         121                  0               0
# 12          98                  0               0
# 13         113                  0               0
# 14         137                  2               0
# 15         115                  0               2
# 16          96                  2               2
# 17         135                  2               2
# 18         112                  2               2
# 19          83                  2               2
# 20         109                  3               2
# 21         124                  2               2
# 22         128                  2               2
# 23         102                  2               2
# 24         105                  2               3
# 25         101                  2               2
# 26         101                  2               1
# 27         102                  2               1
# 28          95                  2               1
# 29          97                  3               1
# 30          96                  1               3
# 31         111                  2               1
# 32         134                  1               3
# 33         114                  3               2
# 34          95                  2               2
# 35          97                  2               2
# 36         104                  2               2
# 37         103                  2               2
# 38         107                  3               2
# 39         121                  1               2
# 40         129                  1               1
# 41         109                  2               2
# 42         108                  2               2
# 43         107                  1               2
# 44         104                  3               1
# 45         122                  2               2
# 46          98                  2               2
# 47          87                  2               3
# 48         116                  2               2
# 49         112                  2               2
# 50          98                  2               2
# 51         121                  2               3
# 52         116                  2               3
# 53         122                  1               4
# 54         111                  2               2
# 55         107                  2               2
# 56          93                  2               2
# 57         118                  2               2
# 58          99                  2               2
# 59         108                  2               2

# %%
# Group by 'Visitor_Last_Game' and 'Home_Last_Game' and apply multiple aggregation functions
grouped_df = season_21_22.groupby(['Visitor_Last_Game', 'Home_Last_Game']).agg(
    Count=('Visitor_Last_Game', 'size'),
    Visitor_Score_Mean=('Visitor Score', 'mean'),
    Home_Score_Mean=('Home Score', 'mean')
).reset_index()

grouped_df
# Out:
#     Visitor_Last_Game  Home_Last_Game  Count  Visitor_Score_Mean  \
# 0                   0               0     14          108.642857
# 1                   0               2      1          113.000000
# 2                   1               1     46          110.608696
# 3                   1               2    150          109.853333
# 4                   1               3     46          106.152174
# 5                   1               4      4          111.250000
# 6                   1               9      1          129.000000
# 7                   2               0      1           95.000000
# 8                   2               1     90          109.322222
# 9                   2               2    544          109.294118
# 10                  2               3    109          109.376147
# 11                  2               4     24          113.750000
# 12                  2               6      1          132.000000
# 13                  2               7      2           95.000000
# 14                  2               8      1          110.000000
# 15                  2               9      1          126.000000
# 16                  3               1     30          115.133333
# 17                  3               2    101          109.633663
# 18                  3               3     50          108.280000
# 19                  3               4      7          108.285714
# 20                  3               6      1          105.000000
# 21                  4               1      8          118.000000
# 22                  4               2     12          110.416667
# 23                  4               3      4          107.250000
# 24                  4               4      2          106.500000
# 25                  4               5      1          104.000000
# 26                  4               6      1          130.000000
# 27                  5               2      3          104.666667
# 28                  5               3      2          102.000000
# 29                  5               7      1          114.000000
# 30                  6               6      3          105.666667
# 31                  7               2      1          122.000000
# 32                  7               7      1           86.000000
# 33                  8               1      2          125.000000
# 34                  8               4      1           99.000000
# 35                  8               7      1          129.000000
# 36                  8               8      5          121.200000
# 37                  8               9      4          110.000000
# 38                  9               8      3          117.666667
#
#     Home_Score_Mean
# 0        113.428571
# 1        115.000000
# 2        112.304348
# 3        112.640000
# 4        111.478261
# 5        116.500000
# 6        125.000000
# 7        137.000000
# 8        108.388889
# 9        110.988971
# 10       110.055046
# 11       118.333333
# 12       117.000000
# 13       112.500000
# 14       115.000000
# 15       123.000000
# 16       110.600000
# 17       111.198020
# 18       112.280000
# 19       107.000000
# 20       113.000000
# 21       112.250000
# 22       117.083333
# 23       116.000000
# 24       113.000000
# 25        98.000000
# 26       117.000000
# 27       116.666667
# 28       104.500000
# 29       115.000000
# 30       115.666667
# 31       115.000000
# 32        93.000000
# 33       102.000000
# 34       144.000000
# 35       106.000000
# 36       108.000000
# 37       108.750000
# 38       128.000000

# %%
filtered_df = grouped_df.query("Visitor_Last_Game != Home_Last_Game")
filtered_df
# Out:
#     Visitor_Last_Game  Home_Last_Game  Count  Visitor_Score_Mean  \
# 1                   0               2      1          113.000000
# 3                   1               2    150          109.853333
# 4                   1               3     46          106.152174
# 5                   1               4      4          111.250000
# 6                   1               9      1          129.000000
# 7                   2               0      1           95.000000
# 8                   2               1     90          109.322222
# 10                  2               3    109          109.376147
# 11                  2               4     24          113.750000
# 12                  2               6      1          132.000000
# 13                  2               7      2           95.000000
# 14                  2               8      1          110.000000
# 15                  2               9      1          126.000000
# 16                  3               1     30          115.133333
# 17                  3               2    101          109.633663
# 19                  3               4      7          108.285714
# 20                  3               6      1          105.000000
# 21                  4               1      8          118.000000
# 22                  4               2     12          110.416667
# 23                  4               3      4          107.250000
# 25                  4               5      1          104.000000
# 26                  4               6      1          130.000000
# 27                  5               2      3          104.666667
# 28                  5               3      2          102.000000
# 29                  5               7      1          114.000000
# 31                  7               2      1          122.000000
# 33                  8               1      2          125.000000
# 34                  8               4      1           99.000000
# 35                  8               7      1          129.000000
# 37                  8               9      4          110.000000
# 38                  9               8      3          117.666667
#
#     Home_Score_Mean
# 1        115.000000
# 3        112.640000
# 4        111.478261
# 5        116.500000
# 6        125.000000
# 7        137.000000
# 8        108.388889
# 10       110.055046
# 11       118.333333
# 12       117.000000
# 13       112.500000
# 14       115.000000
# 15       123.000000
# 16       110.600000
# 17       111.198020
# 19       107.000000
# 20       113.000000
# 21       112.250000
# 22       117.083333
# 23       116.000000
# 25        98.000000
# 26       117.000000
# 27       116.666667
# 28       104.500000
# 29       115.000000
# 31       115.000000
# 33       102.000000
# 34       144.000000
# 35       106.000000
# 37       108.750000
# 38       128.000000

# %%
# Filter rows where 'Count' is less than 5
strip_small_samples = filtered_df[filtered_df['Count'] >= 5]

strip_small_samples
# Out:
#     Visitor_Last_Game  Home_Last_Game  Count  Visitor_Score_Mean  \
# 3                   1               2    150          109.853333
# 4                   1               3     46          106.152174
# 8                   2               1     90          109.322222
# 10                  2               3    109          109.376147
# 11                  2               4     24          113.750000
# 16                  3               1     30          115.133333
# 17                  3               2    101          109.633663
# 19                  3               4      7          108.285714
# 21                  4               1      8          118.000000
# 22                  4               2     12          110.416667
#
#     Home_Score_Mean
# 3        112.640000
# 4        111.478261
# 8        108.388889
# 10       110.055046
# 11       118.333333
# 16       110.600000
# 17       111.198020
# 19       107.000000
# 21       112.250000
# 22       117.083333

# %%
# Calculate the score difference
strip_small_samples['Score_Diff'] = strip_small_samples['Home_Score_Mean'] - strip_small_samples['Visitor_Score_Mean']
strip_small_samples
# Out:
# /var/folders/2c/tr3ggy4904g5pqdkqt7wqyym0000gn/T/ipykernel_24191/3123706657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   strip_small_samples['Score_Diff'] = strip_small_samples['Home_Score_Mean'] - strip_small_samples['Visitor_Score_Mean']
#     Visitor_Last_Game  Home_Last_Game  Count  Visitor_Score_Mean  \
# 3                   1               2    150          109.853333
# 4                   1               3     46          106.152174
# 8                   2               1     90          109.322222
# 10                  2               3    109          109.376147
# 11                  2               4     24          113.750000
# 16                  3               1     30          115.133333
# 17                  3               2    101          109.633663
# 19                  3               4      7          108.285714
# 21                  4               1      8          118.000000
# 22                  4               2     12          110.416667
#
#     Home_Score_Mean  Score_Diff
# 3        112.640000    2.786667
# 4        111.478261    5.326087
# 8        108.388889   -0.933333
# 10       110.055046    0.678899
# 11       118.333333    4.583333
# 16       110.600000   -4.533333
# 17       111.198020    1.564356
# 19       107.000000   -1.285714
# 21       112.250000   -5.750000
# 22       117.083333    6.666667

# %%
# Separate data for home and visitor
visitor_data = strip_small_samples.groupby('Visitor_Last_Game').mean()['Visitor_Score_Mean']
home_data = strip_small_samples.groupby('Home_Last_Game').mean()['Home_Score_Mean']

# Plot Visitor
plt.plot(visitor_data.index, visitor_data.values, label='Points Scored (Visitor)', marker='o')

# Plot Home
plt.plot(home_data.index, home_data.values, label='Points Scored (Home)', marker='x')

plt.xlabel('Days Since Last Game')
plt.ylabel('Average Points Scored')
plt.title('Influence of Rest Days on Points Scored')
plt.legend()

plt.show()

# %%
# Separate data for points scored
visitor_score_data = strip_small_samples.groupby('Visitor_Last_Game').mean()['Visitor_Score_Mean']
home_score_data = strip_small_samples.groupby('Home_Last_Game').mean()['Home_Score_Mean']

# Separate data for points allowed
visitor_allowed_data = strip_small_samples.groupby('Home_Last_Game').mean()['Visitor_Score_Mean']
home_allowed_data = strip_small_samples.groupby('Visitor_Last_Game').mean()['Home_Score_Mean']

# Plot Points Scored (Visitor)
plt.plot(visitor_score_data.index, visitor_score_data.values, label='Points Scored (Visitor)', marker='o', color='blue')

# Plot Points Scored (Home)
plt.plot(home_score_data.index, home_score_data.values, label='Points Scored (Home)', marker='x', color='red')

# Plot Points Allowed (Visitor)
plt.plot(visitor_allowed_data.index, visitor_allowed_data.values, label='Points Allowed (Visitor)', marker='o', linestyle='--', color='green')

# Plot Points Allowed (Home)
plt.plot(home_allowed_data.index, home_allowed_data.values, label='Points Allowed (Home)', marker='x', linestyle='--', color='orange')

plt.xlabel('Days Since Last Game')
plt.ylabel('Average Points')
plt.title('Influence of Rest Days on Points Scored and Allowed')
plt.legend()

plt.show()
